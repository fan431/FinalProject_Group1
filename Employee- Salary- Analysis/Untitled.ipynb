# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import statsmodels.api as sm

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from functools import partial

# %%
from dotenv import load_dotenv

from pathlib import Path

env_path = Path("../../.env-live")

if env_path.exists():
    print('envs Loaded')
    load_dotenv(dotenv_path=env_path)
from jrjModelRegistry.jrjModelRegistry import registerAJrjModel

# %%
salaryDf = pd.read_csv("salary_cleaned.csv")

# %%
salaryDf.shape
# Out:
# (6899, 7)

# %%
salaryDf.columns
# Out:
# Index(['Salary', 'Age', 'Department', 'OverTime', 'StockOptionLevel',
#        'YearsAtCompany', 'ManagerRating'],
#       dtype='object')

# %%
salaryDf.describe()
# Out:
#               Salary          Age  StockOptionLevel  YearsAtCompany  \
# count    6899.000000  6899.000000       6899.000000     6899.000000
# mean   110898.374112    30.604146          0.725467        5.578055
# std     98427.862382     7.986542          0.839724        3.410087
# min     20387.000000    18.000000          0.000000        0.000000
# 25%     44646.000000    25.000000          0.000000        3.000000
# 50%     74458.000000    28.000000          1.000000        6.000000
# 75%    137219.500000    36.000000          1.000000        9.000000
# max    547204.000000    51.000000          3.000000       10.000000
#
#        ManagerRating
# count    6899.000000
# mean        3.460357
# std         0.951560
# min         2.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %%
sm.add_constant(salaryDf[["Age", "Department", "OverTime","StockOptionLevel","YearsAtCompany","ManagerRating"]])
# Out:
#       const  Age  Department OverTime  StockOptionLevel  YearsAtCompany  \
# 0       1.0   30       Sales       No                 1              10
# 1       1.0   30       Sales       No                 1              10
# 2       1.0   30       Sales       No                 1              10
# 3       1.0   30       Sales       No                 1              10
# 4       1.0   30       Sales       No                 1              10
# ...     ...  ...         ...      ...               ...             ...
# 6894    1.0   20  Technology       No                 0               0
# 6895    1.0   27  Technology       No                 3               0
# 6896    1.0   21       Sales       No                 0               0
# 6897    1.0   21  Technology       No                 0               0
# 6898    1.0   20  Technology       No                 0               0
#
#       ManagerRating
# 0               3.0
# 1               2.0
# 2               5.0
# 3               4.0
# 4               3.0
# ...             ...
# 6894            3.0
# 6895            3.0
# 6896            3.0
# 6897            3.0
# 6898            3.0
#
# [6899 rows x 7 columns]

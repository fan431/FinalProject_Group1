# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# https://www.statsmodels.org/stable/index.html
import statsmodels.api as sm

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from functools import partial

# %%
from dotenv import load_dotenv

from pathlib import Path

env_path = Path("../../.env-live")

if env_path.exists():
    print('envs Loaded')
    load_dotenv(dotenv_path=env_path)
from jrjModelRegistry.jrjModelRegistry import registerAJrjModel

# %%
import os
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /Users/zihansu/github/FinalProject-Group1/Employee- Salary- Analysis

# %%
from pathlib import Path
import pandas as pd

csv_path = Path("../dataset-employee/preprocessed_employee_data.csv")

print("File exists:", csv_path.exists())

if csv_path.exists():
    salaryDf = pd.read_csv(csv_path)
    salaryDf.head()
# Out:
# File exists: True

# %%
salaryDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6899 entries, 0 to 6898
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   EmployeeID                       6899 non-null   object
#  1   Attrition                        6899 non-null   int64
#  2   Gender                           6899 non-null   object
#  3   Age                              6899 non-null   int64
#  4   Department                       6899 non-null   object
#  5   BusinessTravel                   6899 non-null   object
#  6   MaritalStatus                    6899 non-null   object
#  7   DistanceFromHome (KM)            6899 non-null   int64
#  8   Salary                           6899 non-null   int64
#  9   StockOptionLevel                 6899 non-null   int64
#  10  OverTime                         6899 non-null   object
#  11  YearsAtCompany                   6899 non-null   int64
#  12  YearsInMostRecentRole            6899 non-null   int64
#  13  YearsSinceLastPromotion          6899 non-null   int64
#  14  YearsWithCurrManager             6899 non-null   int64
#  15  Ethnicity                        6899 non-null   object
#  16  EducationLevel                   6899 non-null   object
#  17  EnvironmentSatisfaction          6899 non-null   float64
#  18  JobSatisfaction                  6899 non-null   float64
#  19  RelationshipSatisfaction         6899 non-null   float64
#  20  WorkLifeBalance                  6899 non-null   float64
#  21  TrainingOpportunitiesWithinYear  6899 non-null   float64
#  22  TrainingOpportunitiesTaken       6899 non-null   float64
#  23  SelfRating                       6899 non-null   float64
#  24  ManagerRating                    6899 non-null   float64
#  25  EnvironmentSatisfaction_Label    6899 non-null   object
#  26  JobSatisfaction_Label            6899 non-null   object
#  27  RelationshipSatisfaction_Label   6899 non-null   object
#  28  WorkLifeBalance_Label            6899 non-null   object
#  29  ManagerRating_Label              6899 non-null   object
#  30  SelfRating_Label                 6899 non-null   object
#  31  TrainingUtilizationRate          6899 non-null   float64
# dtypes: float64(9), int64(9), object(14)
# memory usage: 1.7+ MB

# %%
salaryDf.head()
# Out:
#   EmployeeID  Attrition  Gender  Age Department BusinessTravel MaritalStatus  \
# 0  3012-1A41          0  Female   30      Sales    Some Travel      Divorced
# 1  3012-1A41          0  Female   30      Sales    Some Travel      Divorced
# 2  3012-1A41          0  Female   30      Sales    Some Travel      Divorced
# 3  3012-1A41          0  Female   30      Sales    Some Travel      Divorced
# 4  3012-1A41          0  Female   30      Sales    Some Travel      Divorced
#
#    DistanceFromHome (KM)  Salary  StockOptionLevel  ...  \
# 0                     27  102059                 1  ...
# 1                     27  102059                 1  ...
# 2                     27  102059                 1  ...
# 3                     27  102059                 1  ...
# 4                     27  102059                 1  ...
#
#   TrainingOpportunitiesTaken  SelfRating  ManagerRating  \
# 0                        0.0         3.0            3.0
# 1                        1.0         3.0            2.0
# 2                        0.0         5.0            5.0
# 3                        1.0         5.0            4.0
# 4                        0.0         4.0            3.0
#
#    EnvironmentSatisfaction_Label  JobSatisfaction_Label  \
# 0                        Neutral                Neutral
# 1                     Satisfied              Satisfied
# 2                 Very Satisfied         Very Satisfied
# 3              Very Dissatisfied                Neutral
# 4                        Neutral             Satisfied
#
#   RelationshipSatisfaction_Label WorkLifeBalance_Label   ManagerRating_Label  \
# 0                   Dissatisfied            Satisfied      Meets Expectation
# 1                 Very Satisfied          Dissatisfied     Needs Improvement
# 2                     Satisfied             Satisfied       Above and Beyond
# 3                   Dissatisfied               Neutral  Exceeds Expectation
# 4                   Dissatisfied               Neutral     Meets Expectation
#
#        SelfRating_Label  TrainingUtilizationRate
# 0     Meets Expectation                 0.000000
# 1     Meets Expectation                 0.333332
# 2      Above and Beyond                 0.000000
# 3      Above and Beyond                 0.333332
# 4  Exceeds Expectation                  0.000000
#
# [5 rows x 32 columns]

# %%
# Select a minimal set of features that are most likely to influence Salary
columns_to_keep = [
    'Salary',
    'Age',
    'Department',
    'OverTime',
    'StockOptionLevel',
    'YearsAtCompany',
    'ManagerRating'
]

salaryDf_model = salaryDf[columns_to_keep].copy()
salaryDf_model.head()
# Out:
#    Salary  Age Department OverTime  StockOptionLevel  YearsAtCompany  \
# 0  102059   30      Sales       No                 1              10
# 1  102059   30      Sales       No                 1              10
# 2  102059   30      Sales       No                 1              10
# 3  102059   30      Sales       No                 1              10
# 4  102059   30      Sales       No                 1              10
#
#    ManagerRating
# 0            3.0
# 1            2.0
# 2            5.0
# 3            4.0
# 4            3.0

# %%
# Save the selected feature DataFrame to a new CSV file
salaryDf_model.to_csv("../salary_cleaned.csv", index=False)
